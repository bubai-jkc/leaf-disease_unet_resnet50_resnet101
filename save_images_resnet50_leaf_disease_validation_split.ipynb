# %% [markdown]
# <a href="https://colab.research.google.com/github/bubai-jkc/leaf-disease_unet_resnet50_resnet101/blob/main/save_images_resnet50_leaf_disease_validation_split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !kaggle datasets download -d fakhrealam9537/leaf-disease-segmentation-dataset
import zipfile
zip_ref = zipfile.ZipFile('/content/leaf-disease-segmentation-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/fakhrealam9537/leaf-disease-segmentation-dataset
# License(s): CC0-1.0
# Downloading leaf-disease-segmentation-dataset.zip to /content
#  97% 490M/503M [00:01<00:00, 323MB/s]
# 100% 503M/503M [00:01<00:00, 420MB/s]

# %%
#learning rate 1e-4 to 1e-5, epochs=40 to 60, added=nn.Dropout2d(0.2), weight_decay=1e-5 is added in optimizer
import os
import zipfile
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms, models
from tqdm import tqdm

DATASET_PATH = "/content/aug_data/aug_data"
IMG_SIZE = (256, 256)
BATCH_SIZE = 8
LEARNING_RATE = 1e-5
NUM_EPOCHS = 120
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class LeafDiseaseDataset(Dataset):
    def __init__(self, root_dir, img_size=IMG_SIZE, augment=False):
        self.images_dir = os.path.join(root_dir, "images")
        self.masks_dir  = os.path.join(root_dir, "masks")
        self.img_size = img_size
        self.image_files = sorted(os.listdir(self.images_dir))
        self.augment = augment
        self.normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_name = self.image_files[idx]
        img_path  = os.path.join(self.images_dir, img_name)
        mask_path = os.path.join(self.masks_dir, img_name.replace(".jpg", ".png"))

        image = Image.open(img_path).convert("RGB")
        mask  = Image.open(mask_path).convert("L")

        image = image.resize(self.img_size)
        mask  = mask.resize(self.img_size, resample=Image.NEAREST)
        if self.augment:
            if np.random.random() > 0.5:
                image = transforms.functional.hflip(image)
                mask = transforms.functional.hflip(mask)
            if np.random.random() > 0.5:
                image = transforms.functional.vflip(image)
                mask = transforms.functional.vflip(mask)
            angle = np.random.randint(-30, 30)
            image = transforms.functional.rotate(image, angle)
            mask = transforms.functional.rotate(mask, angle)

        image = transforms.ToTensor()(image)
        image = self.normalize(image)

        mask = transforms.ToTensor()(mask)
        mask = (mask > 0).float()

        return image, mask

full_dataset = LeafDiseaseDataset(DATASET_PATH, augment=True)
train_size = int(0.75 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

val_dataset.dataset.augment = False

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

class DoubleConv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
            nn.Dropout2d(0.2),
            nn.Conv2d(out_ch, out_ch, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True)
        )
    def forward(self, x): return self.conv(x)

class DecoderBlock(nn.Module):
    def __init__(self, in_ch, skip_ch, out_ch):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_ch, in_ch // 2, kernel_size=2, stride=2)
        self.conv = DoubleConv(in_ch // 2 + skip_ch, out_ch)
    def forward(self, x, skip):
        x = self.up(x)
        x = torch.cat([x, skip], dim=1)
        return self.conv(x)

class ResNet50UNet(nn.Module):
    def __init__(self, n_classes=1):
        super().__init__()
        base_model = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
        base_layers = list(base_model.children())
        self.init_conv = nn.Sequential(*base_layers[:3])
        self.pool = base_layers[3]
        self.layer1 = base_layers[4]
        self.layer2 = base_layers[5]
        self.layer3 = base_layers[6]
        self.layer4 = base_layers[7]

        self.up1 = DecoderBlock(2048, 1024, 512)
        self.up2 = DecoderBlock(512, 512, 256)
        self.up3 = DecoderBlock(256, 256, 128)
        self.up4 = DecoderBlock(128, 64, 64)

        self.final_up = nn.ConvTranspose2d(64, 32, kernel_size=2, stride=2)
        self.final_conv = nn.Conv2d(32, n_classes, kernel_size=1)

    def forward(self, x):
        x0 = self.init_conv(x)
        x1 = self.pool(x0)
        x1 = self.layer1(x1)
        x2 = self.layer2(x1)
        x3 = self.layer3(x2)
        x4 = self.layer4(x3)

        d1 = self.up1(x4, x3)
        d2 = self.up2(d1, x2)
        d3 = self.up3(d2, x1)
        d4 = self.up4(d3, x0)

        return self.final_conv(self.final_up(d4))

def mean_iou(preds, masks, eps=1e-6):
    preds = (torch.sigmoid(preds) > 0.5).float()
    intersection = (preds * masks).sum(dim=(1, 2, 3))
    union = preds.sum(dim=(1, 2, 3)) + masks.sum(dim=(1, 2, 3)) - intersection
    return ((intersection + eps) / (union + eps)).mean()

model = ResNet50UNet().to(DEVICE)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=1e-5)

train_losses, val_losses = [], []
train_ious, val_ious = [], []
best_iou = 0.0

for epoch in range(NUM_EPOCHS):
    model.train()
    running_loss, running_iou = 0.0, 0.0
    pbar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{NUM_EPOCHS} [Train]", leave=False)

    for images, masks in pbar:
        images, masks = images.to(DEVICE), masks.to(DEVICE)
        outputs = model(images)
        loss = criterion(outputs, masks)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)
        running_iou  += mean_iou(outputs, masks).item() * images.size(0)

    avg_train_loss = running_loss / len(train_dataset)
    avg_train_iou = running_iou / len(train_dataset)
    train_losses.append(avg_train_loss)
    train_ious.append(avg_train_iou)

    model.eval()
    running_v_loss, running_v_iou = 0.0, 0.0
    with torch.no_grad():
        for images, masks in val_loader:
            images, masks = images.to(DEVICE), masks.to(DEVICE)
            outputs = model(images)
            v_loss = criterion(outputs, masks)
            running_v_loss += v_loss.item() * images.size(0)
            running_v_iou  += mean_iou(outputs, masks).item() * images.size(0)

    avg_val_loss = running_v_loss / len(val_dataset)
    avg_val_iou = running_v_iou / len(val_dataset)
    val_losses.append(avg_val_loss)
    val_ious.append(avg_val_iou)

    print(f"Epoch {epoch+1}: Train Loss {avg_train_loss:.4f} | Val Loss {avg_val_loss:.4f} | Val IoU {avg_val_iou:.4f}")

    if avg_val_iou > best_iou:
        best_iou = avg_val_iou
        torch.save(model.state_dict(), "best_model.pth")
        print("--> Saved New Best Model!")


plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.title('Loss Curves')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_ious, label='Train IoU')
plt.plot(val_ious, label='Val IoU')
plt.title('mIoU Curves')
plt.legend()
plt.show()

def visualize(model, loader):
    model.load_state_dict(torch.load("best_model.pth"))
    model.eval()
    images, masks = next(iter(loader))
    preds = (torch.sigmoid(model(images.to(DEVICE))) > 0.5).float()

    for i in range(3):
        img = images[i].cpu().permute(1,2,0).numpy()
        img = np.clip(img * [0.229, 0.224, 0.225] + [0.485, 0.456, 0.406], 0, 1)
        plt.figure(figsize=(10,3))
        for j, (title, data) in enumerate(zip(["Img", "GT", "Pred"], [img, masks[i][0], preds[i][0].cpu()])):
            plt.subplot(1,3,j+1); plt.imshow(data, cmap='gray' if j>0 else None); plt.title(title); plt.axis('off')
        plt.show()

visualize(model, val_loader)
# Out:
# Epoch 1: Train Loss 0.6773 | Val Loss 0.6088 | Val IoU 0.4067
# --> Saved New Best Model!
# Epoch 2: Train Loss 0.5603 | Val Loss 0.5179 | Val IoU 0.5559
# --> Saved New Best Model!
# Epoch 3: Train Loss 0.4746 | Val Loss 0.4518 | Val IoU 0.6036
# --> Saved New Best Model!
# Epoch 4: Train Loss 0.4018 | Val Loss 0.3608 | Val IoU 0.6613
# --> Saved New Best Model!
# Epoch 5: Train Loss 0.3384 | Val Loss 0.2920 | Val IoU 0.6786
# --> Saved New Best Model!
# Epoch 6: Train Loss 0.2865 | Val Loss 0.2640 | Val IoU 0.6863
# --> Saved New Best Model!
# Epoch 7: Train Loss 0.2462 | Val Loss 0.2397 | Val IoU 0.6928
# --> Saved New Best Model!
# Epoch 8: Train Loss 0.2131 | Val Loss 0.2054 | Val IoU 0.6986
# --> Saved New Best Model!
# Epoch 9: Train Loss 0.1879 | Val Loss 0.1744 | Val IoU 0.7106
# --> Saved New Best Model!
# Epoch 10: Train Loss 0.1684 | Val Loss 0.1591 | Val IoU 0.7158
# --> Saved New Best Model!
# Epoch 11: Train Loss 0.1477 | Val Loss 0.1554 | Val IoU 0.7140
# Epoch 12: Train Loss 0.1337 | Val Loss 0.1350 | Val IoU 0.7284
# --> Saved New Best Model!
# Epoch 13: Train Loss 0.1243 | Val Loss 0.1236 | Val IoU 0.7308
# --> Saved New Best Model!
# Epoch 14: Train Loss 0.1123 | Val Loss 0.1150 | Val IoU 0.7339
# --> Saved New Best Model!
# Epoch 15: Train Loss 0.1048 | Val Loss 0.1146 | Val IoU 0.7316
# Epoch 16: Train Loss 0.0962 | Val Loss 0.1069 | Val IoU 0.7374
# --> Saved New Best Model!
# Epoch 17: Train Loss 0.0916 | Val Loss 0.1082 | Val IoU 0.7353
# Epoch 18: Train Loss 0.0872 | Val Loss 0.1023 | Val IoU 0.7408
# --> Saved New Best Model!
# Epoch 19: Train Loss 0.0833 | Val Loss 0.0960 | Val IoU 0.7467
# --> Saved New Best Model!
# Epoch 20: Train Loss 0.0786 | Val Loss 0.0911 | Val IoU 0.7407
# Epoch 21: Train Loss 0.0730 | Val Loss 0.0886 | Val IoU 0.7470
# --> Saved New Best Model!
# Epoch 22: Train Loss 0.0716 | Val Loss 0.0874 | Val IoU 0.7495
# --> Saved New Best Model!
# Epoch 23: Train Loss 0.0668 | Val Loss 0.0902 | Val IoU 0.7510
# --> Saved New Best Model!
# Epoch 24: Train Loss 0.0640 | Val Loss 0.0871 | Val IoU 0.7563
# --> Saved New Best Model!
# Epoch 25: Train Loss 0.0627 | Val Loss 0.0869 | Val IoU 0.7543
# Epoch 26: Train Loss 0.0593 | Val Loss 0.0877 | Val IoU 0.7553
# Epoch 27: Train Loss 0.0599 | Val Loss 0.0861 | Val IoU 0.7589
# --> Saved New Best Model!
# Epoch 28: Train Loss 0.0561 | Val Loss 0.0849 | Val IoU 0.7583
# Epoch 29: Train Loss 0.0543 | Val Loss 0.0842 | Val IoU 0.7581
# Epoch 30: Train Loss 0.0521 | Val Loss 0.0834 | Val IoU 0.7604
# --> Saved New Best Model!
# Epoch 31: Train Loss 0.0510 | Val Loss 0.0815 | Val IoU 0.7633
# --> Saved New Best Model!
# Epoch 32: Train Loss 0.0501 | Val Loss 0.0833 | Val IoU 0.7641
# --> Saved New Best Model!
# Epoch 33: Train Loss 0.0490 | Val Loss 0.0837 | Val IoU 0.7615
# Epoch 34: Train Loss 0.0476 | Val Loss 0.0826 | Val IoU 0.7673
# --> Saved New Best Model!
# Epoch 35: Train Loss 0.0471 | Val Loss 0.0811 | Val IoU 0.7671
# Epoch 36: Train Loss 0.0459 | Val Loss 0.0819 | Val IoU 0.7686
# --> Saved New Best Model!
# Epoch 37: Train Loss 0.0453 | Val Loss 0.0855 | Val IoU 0.7633
# Epoch 38: Train Loss 0.0448 | Val Loss 0.0823 | Val IoU 0.7681
# Epoch 39: Train Loss 0.0439 | Val Loss 0.0878 | Val IoU 0.7592
# Epoch 40: Train Loss 0.0428 | Val Loss 0.0833 | Val IoU 0.7685
# Epoch 41: Train Loss 0.0423 | Val Loss 0.0825 | Val IoU 0.7709
# --> Saved New Best Model!
# Epoch 42: Train Loss 0.0411 | Val Loss 0.0864 | Val IoU 0.7683
# Epoch 43: Train Loss 0.0411 | Val Loss 0.0833 | Val IoU 0.7727
# --> Saved New Best Model!
# Epoch 44: Train Loss 0.0405 | Val Loss 0.0837 | Val IoU 0.7728
# --> Saved New Best Model!
# Epoch 45: Train Loss 0.0397 | Val Loss 0.0835 | Val IoU 0.7719
# Epoch 46: Train Loss 0.0394 | Val Loss 0.0858 | Val IoU 0.7726
# Epoch 47: Train Loss 0.0394 | Val Loss 0.0964 | Val IoU 0.7545
# Epoch 48: Train Loss 0.0394 | Val Loss 0.0861 | Val IoU 0.7712
# Epoch 49: Train Loss 0.0382 | Val Loss 0.0850 | Val IoU 0.7729
# --> Saved New Best Model!
# Epoch 50: Train Loss 0.0374 | Val Loss 0.0881 | Val IoU 0.7722
# Epoch 51: Train Loss 0.0374 | Val Loss 0.0862 | Val IoU 0.7752
# --> Saved New Best Model!
# Epoch 52: Train Loss 0.0362 | Val Loss 0.0856 | Val IoU 0.7763
# --> Saved New Best Model!
# Epoch 53: Train Loss 0.0360 | Val Loss 0.0866 | Val IoU 0.7749
# Epoch 54: Train Loss 0.0352 | Val Loss 0.0857 | Val IoU 0.7767
# --> Saved New Best Model!
# Epoch 55: Train Loss 0.0354 | Val Loss 0.0902 | Val IoU 0.7722
# Epoch 56: Train Loss 0.0355 | Val Loss 0.0885 | Val IoU 0.7740
# Epoch 57: Train Loss 0.0345 | Val Loss 0.0861 | Val IoU 0.7758
# Epoch 58: Train Loss 0.0348 | Val Loss 0.0884 | Val IoU 0.7751
# Epoch 59: Train Loss 0.0343 | Val Loss 0.0851 | Val IoU 0.7759
# Epoch 60: Train Loss 0.0335 | Val Loss 0.0859 | Val IoU 0.7771
# --> Saved New Best Model!
# Epoch 61: Train Loss 0.0334 | Val Loss 0.0873 | Val IoU 0.7770
# Epoch 62: Train Loss 0.0331 | Val Loss 0.0882 | Val IoU 0.7753
# Epoch 63: Train Loss 0.0331 | Val Loss 0.0897 | Val IoU 0.7720
# Epoch 64: Train Loss 0.0330 | Val Loss 0.0893 | Val IoU 0.7764
# Epoch 65: Train Loss 0.0325 | Val Loss 0.0923 | Val IoU 0.7737
# Epoch 66: Train Loss 0.0322 | Val Loss 0.0892 | Val IoU 0.7758
# Epoch 67: Train Loss 0.0319 | Val Loss 0.0899 | Val IoU 0.7756
# Epoch 68: Train Loss 0.0318 | Val Loss 0.0895 | Val IoU 0.7762
# Epoch 69: Train Loss 0.0310 | Val Loss 0.0887 | Val IoU 0.7786
# --> Saved New Best Model!
# Epoch 70: Train Loss 0.0312 | Val Loss 0.0916 | Val IoU 0.7751
# Epoch 71: Train Loss 0.0304 | Val Loss 0.0904 | Val IoU 0.7782
# Epoch 72: Train Loss 0.0305 | Val Loss 0.0905 | Val IoU 0.7778
# Epoch 73: Train Loss 0.0302 | Val Loss 0.0935 | Val IoU 0.7791
# --> Saved New Best Model!
# Epoch 74: Train Loss 0.0303 | Val Loss 0.0924 | Val IoU 0.7767
# Epoch 75: Train Loss 0.0299 | Val Loss 0.0898 | Val IoU 0.7796
# --> Saved New Best Model!
# Epoch 76: Train Loss 0.0297 | Val Loss 0.0900 | Val IoU 0.7809
# --> Saved New Best Model!
# Epoch 77: Train Loss 0.0295 | Val Loss 0.0902 | Val IoU 0.7774
# Epoch 78: Train Loss 0.0290 | Val Loss 0.0906 | Val IoU 0.7801
# Epoch 79: Train Loss 0.0291 | Val Loss 0.0891 | Val IoU 0.7802
# Epoch 80: Train Loss 0.0284 | Val Loss 0.0889 | Val IoU 0.7797
# Epoch 81: Train Loss 0.0282 | Val Loss 0.0928 | Val IoU 0.7811
# --> Saved New Best Model!
# Epoch 82: Train Loss 0.0281 | Val Loss 0.0916 | Val IoU 0.7803
# Epoch 83: Train Loss 0.0280 | Val Loss 0.0921 | Val IoU 0.7810
# Epoch 84: Train Loss 0.0280 | Val Loss 0.0920 | Val IoU 0.7785
# Epoch 85: Train Loss 0.0282 | Val Loss 0.0923 | Val IoU 0.7821
# --> Saved New Best Model!
# Epoch 86: Train Loss 0.0274 | Val Loss 0.0906 | Val IoU 0.7820
# Epoch 87: Train Loss 0.0271 | Val Loss 0.0917 | Val IoU 0.7773
# Epoch 88: Train Loss 0.0271 | Val Loss 0.0918 | Val IoU 0.7830
# --> Saved New Best Model!
# Epoch 89: Train Loss 0.0272 | Val Loss 0.0936 | Val IoU 0.7800
# Epoch 90: Train Loss 0.0271 | Val Loss 0.0930 | Val IoU 0.7817
# Epoch 91: Train Loss 0.0265 | Val Loss 0.0946 | Val IoU 0.7811
# Epoch 92: Train Loss 0.0265 | Val Loss 0.0916 | Val IoU 0.7836
# --> Saved New Best Model!
# Epoch 93: Train Loss 0.0261 | Val Loss 0.0937 | Val IoU 0.7823
# Epoch 94: Train Loss 0.0264 | Val Loss 0.0955 | Val IoU 0.7827
# Epoch 95: Train Loss 0.0260 | Val Loss 0.0963 | Val IoU 0.7812
# Epoch 96: Train Loss 0.0258 | Val Loss 0.0924 | Val IoU 0.7813
# Epoch 97: Train Loss 0.0255 | Val Loss 0.0943 | Val IoU 0.7798
# Epoch 98: Train Loss 0.0254 | Val Loss 0.0945 | Val IoU 0.7832
# Epoch 99: Train Loss 0.0252 | Val Loss 0.1006 | Val IoU 0.7775
# Epoch 100: Train Loss 0.0251 | Val Loss 0.0946 | Val IoU 0.7824
# Epoch 101: Train Loss 0.0252 | Val Loss 0.0945 | Val IoU 0.7846
# --> Saved New Best Model!
# Epoch 102: Train Loss 0.0249 | Val Loss 0.0969 | Val IoU 0.7814
# Epoch 103: Train Loss 0.0248 | Val Loss 0.0987 | Val IoU 0.7816
# Epoch 104: Train Loss 0.0246 | Val Loss 0.1011 | Val IoU 0.7806
# Epoch 105: Train Loss 0.0245 | Val Loss 0.0960 | Val IoU 0.7815
# Epoch 106: Train Loss 0.0245 | Val Loss 0.0967 | Val IoU 0.7814
# Epoch 107: Train Loss 0.0243 | Val Loss 0.0962 | Val IoU 0.7838
# Epoch 108: Train Loss 0.0239 | Val Loss 0.1034 | Val IoU 0.7821
# Epoch 109: Train Loss 0.0239 | Val Loss 0.1023 | Val IoU 0.7819
# Epoch 110: Train Loss 0.0236 | Val Loss 0.0976 | Val IoU 0.7847
# --> Saved New Best Model!
# Epoch 111: Train Loss 0.0237 | Val Loss 0.1040 | Val IoU 0.7805
# Epoch 112: Train Loss 0.0235 | Val Loss 0.0984 | Val IoU 0.7811
# Epoch 113: Train Loss 0.0234 | Val Loss 0.0976 | Val IoU 0.7841
# Epoch 114: Train Loss 0.0233 | Val Loss 0.0987 | Val IoU 0.7836
# Epoch 115: Train Loss 0.0233 | Val Loss 0.1007 | Val IoU 0.7834
# Epoch 116: Train Loss 0.0235 | Val Loss 0.0996 | Val IoU 0.7808
# Epoch 117: Train Loss 0.0243 | Val Loss 0.0990 | Val IoU 0.7822
# Epoch 118: Train Loss 0.0230 | Val Loss 0.1006 | Val IoU 0.7839
# Epoch 119: Train Loss 0.0229 | Val Loss 0.0989 | Val IoU 0.7846
# Epoch 120: Train Loss 0.0227 | Val Loss 0.1024 | Val IoU 0.7827

# %%
import os
import zipfile
import shutil
from google.colab import files

def save_and_download_deviations(model, loader, top_k=100, save_dir="top_deviations"):
    # Load the best saved weights from your training run
    if os.path.exists("best_model.pth"):
        model.load_state_dict(torch.load("best_model.pth"))
    model.eval()

    # Setup save directory
    if os.path.exists(save_dir):
        shutil.rmtree(save_dir)
    os.makedirs(save_dir, exist_ok=True)

    results = []
    print(f"Analyzing all validation images to find the top {top_k} deviations...")

    #Compute error for every image in the dataset
    with torch.no_grad():
        for images, masks in tqdm(loader):
            images_gpu = images.to(DEVICE)
            masks_gpu = masks.to(DEVICE)
            outputs = model(images_gpu)
            preds = (torch.sigmoid(outputs) > 0.5).float()

            for i in range(images.size(0)):
                pred = preds[i]
                gt = masks_gpu[i]
                intersection = (pred * gt).sum()
                union = pred.sum() + gt.sum() - intersection + 1e-6
                iou = (intersection / union).item()
                results.append({
                    "image": images[i],
                    "gt": masks[i][0],
                    "pred": pred[0].cpu(),
                    "iou": iou,
                    "error": 1 - iou
                })

    # Sort by highest error (lowest IoU)
    results = sorted(results, key=lambda x: x["error"], reverse=True)[:top_k]

    print(f"Generating and saving {len(results)} plots to '{save_dir}'...")
    for idx, item in enumerate(results):
        img = item["image"].permute(1,2,0).numpy()
        # Denormalize image for correct display
        img = np.clip(img * [0.229, 0.224, 0.225] + [0.485, 0.456, 0.406], 0, 1)

        plt.figure(figsize=(15, 5))

        plt.subplot(1, 3, 1)
        plt.imshow(img)
        plt.title("Original Leaf")
        plt.axis("off")

        plt.subplot(1, 3, 2)
        plt.imshow(item["gt"], cmap="gray")
        plt.title("Ground Truth Mask")
        plt.axis("off")

        plt.subplot(1, 3, 3)
        plt.imshow(item["pred"], cmap="gray")
        plt.title(f"Model Prediction\nIoU: {item['iou']:.4f}")
        plt.axis("off")

        # Save figure as high-quality PNG
        save_path = os.path.join(save_dir, f"rank_{idx+1:03d}_iou_{item['iou']:.2f}.png")
        plt.savefig(save_path, bbox_inches='tight', dpi=100)
        plt.close()

    # Create Zip Archive
    zip_filename = "leaf_disease_deviations.zip"
    with zipfile.ZipFile(zip_filename, 'w') as zipf:
        for root, _, files_in_dir in os.walk(save_dir):
            for file in files_in_dir:
                zipf.write(os.path.join(root, file), arcname=file)

    print(f"\n Created {zip_filename} containing {len(results)} images.")

    # download
    files.download(zip_filename)

save_and_download_deviations(model, val_loader, top_k=100)
