# %% [markdown]
# <a href="https://colab.research.google.com/github/bubai-jkc/leaf-disease_unet_resnet50_resnet101/blob/main/Resnet50_leaf_disease_ConvBlock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !kaggle datasets download -d fakhrealam9537/leaf-disease-segmentation-dataset
import zipfile
zip_ref = zipfile.ZipFile('/content/leaf-disease-segmentation-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/fakhrealam9537/leaf-disease-segmentation-dataset
# License(s): CC0-1.0
# Downloading leaf-disease-segmentation-dataset.zip to /content
#  91% 457M/503M [00:02<00:00, 90.3MB/s]
# 100% 503M/503M [00:02<00:00, 180MB/s]

# %%
import os
import zipfile
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from tqdm import tqdm
DATASET_PATH = "/content/aug_data/aug_data"
IMG_SIZE = (256, 256)
BATCH_SIZE = 8
LEARNING_RATE = 1e-4
NUM_EPOCHS = 60
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
class LeafDiseaseDataset(Dataset):
    def __init__(self, root_dir, img_size=IMG_SIZE):
        self.images_dir = os.path.join(root_dir, "images")
        self.masks_dir  = os.path.join(root_dir, "masks")
        self.img_size = img_size
        self.image_files = sorted(os.listdir(self.images_dir))
        self.img_transform = transforms.Compose([
            transforms.Resize(self.img_size),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_name = self.image_files[idx]
        img_path  = os.path.join(self.images_dir, img_name)
        mask_path = os.path.join(self.masks_dir, img_name.replace(".jpg", ".png"))
        image = Image.open(img_path).convert("RGB")
        mask  = Image.open(mask_path).convert("L")
        image = self.img_transform(image)
        mask = mask.resize(self.img_size, resample=Image.NEAREST)
        mask = transforms.ToTensor()(mask)
        mask = (mask > 0).float()
        return image, mask

dataset = LeafDiseaseDataset(DATASET_PATH)
data_loader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
class ConvBlock(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True)
        )
    def forward(self, x): return self.conv(x)

class DecoderBlock(nn.Module):
    def __init__(self, in_ch, skip_ch, out_ch):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_ch, in_ch // 2, kernel_size=2, stride=2)
        self.conv = nn.Sequential(
            ConvBlock(in_ch // 2 + skip_ch, out_ch),
            ConvBlock(out_ch, out_ch)
        )

    def forward(self, x, skip):
        x = self.up(x)
        x = torch.cat([x, skip], dim=1)
        return self.conv(x)

class ResNet50UNet(nn.Module):
    def __init__(self, n_classes=1):
        super().__init__()
        base_model = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
        base_layers = list(base_model.children())
        self.init_conv = nn.Sequential(*base_layers[:3])
        self.pool = base_layers[3]
        self.layer1 = base_layers[4]
        self.layer2 = base_layers[5]
        self.layer3 = base_layers[6]
        self.layer4 = base_layers[7]

        self.up1 = DecoderBlock(2048, 1024, 512)
        self.up2 = DecoderBlock(512, 512, 256)
        self.up3 = DecoderBlock(256, 256, 128)
        self.up4 = DecoderBlock(128, 64, 64)

        self.final_up = nn.ConvTranspose2d(64, 32, kernel_size=2, stride=2)
        self.final_conv = nn.Conv2d(32, n_classes, kernel_size=1)

    def forward(self, x):
        # Encoder
        x0 = self.init_conv(x)
        x1 = self.pool(x0)
        x1 = self.layer1(x1)
        x2 = self.layer2(x1)
        x3 = self.layer3(x2)
        x4 = self.layer4(x3)

        d1 = self.up1(x4, x3)
        d2 = self.up2(d1, x2)
        d3 = self.up3(d2, x1)
        d4 = self.up4(d3, x0)

        out = self.final_up(d4)
        return self.final_conv(out)

def mean_iou(preds, masks, eps=1e-6):
    preds = (torch.sigmoid(preds) > 0.5).float()
    intersection = (preds * masks).sum(dim=(1, 2, 3))
    union = preds.sum(dim=(1, 2, 3)) + masks.sum(dim=(1, 2, 3)) - intersection
    return ((intersection + eps) / (union + eps)).mean()

model = ResNet50UNet().to(DEVICE)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)


for epoch in range(NUM_EPOCHS):
    model.train()
    epoch_loss, epoch_iou = 0.0, 0.0
    pbar = tqdm(data_loader, desc=f"Epoch {epoch+1}/{NUM_EPOCHS}", leave=False)

    for images, masks in pbar:
        images, masks = images.to(DEVICE), masks.to(DEVICE)

        outputs = model(images)
        loss = criterion(outputs, masks)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        batch_loss = loss.item()
        batch_iou = mean_iou(outputs, masks).item()
        epoch_loss += batch_loss * images.size(0)
        epoch_iou  += batch_iou * images.size(0)

        pbar.set_postfix(loss=f"{batch_loss:.4f}", iou=f"{batch_iou:.4f}")

    print(f"Summary Epoch [{epoch+1}/{NUM_EPOCHS}] - Avg Loss: {epoch_loss/len(dataset):.4f} - Avg mIoU: {epoch_iou/len(dataset):.4f}")


def visualize_results(model, dataloader, num_samples=5):
    model.eval()
    with torch.no_grad():
        images, masks = next(iter(dataloader))
        images, masks = images.to(DEVICE), masks.to(DEVICE)
        preds = (torch.sigmoid(model(images)) > 0.5).float()
        for i in range(min(num_samples, images.size(0))):
            img = images[i].cpu().permute(1, 2, 0).numpy()
            img = np.clip(img * [0.229, 0.224, 0.225] + [0.485, 0.456, 0.406], 0, 1)
            fig, ax = plt.subplots(1, 3, figsize=(12, 4))
            ax[0].imshow(img); ax[0].set_title("Input")
            ax[1].imshow(masks[i].cpu().squeeze(), cmap="gray"); ax[1].set_title("GT")
            ax[2].imshow(preds[i].cpu().squeeze(), cmap="gray"); ax[2].set_title("Pred")
            plt.show()

visualize_results(model, data_loader)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 138MB/s]
# Summary Epoch [1/60] - Avg Loss: 0.3184 - Avg mIoU: 0.5545
# Summary Epoch [2/60] - Avg Loss: 0.1338 - Avg mIoU: 0.6817
# Summary Epoch [3/60] - Avg Loss: 0.0984 - Avg mIoU: 0.7297
# Summary Epoch [4/60] - Avg Loss: 0.0823 - Avg mIoU: 0.7573
# Summary Epoch [5/60] - Avg Loss: 0.0718 - Avg mIoU: 0.7774
# Summary Epoch [6/60] - Avg Loss: 0.0635 - Avg mIoU: 0.7951
# Summary Epoch [7/60] - Avg Loss: 0.0587 - Avg mIoU: 0.8049
# Summary Epoch [8/60] - Avg Loss: 0.0541 - Avg mIoU: 0.8161
# Summary Epoch [9/60] - Avg Loss: 0.0524 - Avg mIoU: 0.8216
# Summary Epoch [10/60] - Avg Loss: 0.0478 - Avg mIoU: 0.8324
# Summary Epoch [11/60] - Avg Loss: 0.0555 - Avg mIoU: 0.8152
# Summary Epoch [12/60] - Avg Loss: 0.0485 - Avg mIoU: 0.8323
# Summary Epoch [13/60] - Avg Loss: 0.0426 - Avg mIoU: 0.8476
# Summary Epoch [14/60] - Avg Loss: 0.0408 - Avg mIoU: 0.8528
# Summary Epoch [15/60] - Avg Loss: 0.0389 - Avg mIoU: 0.8586
# Summary Epoch [16/60] - Avg Loss: 0.0377 - Avg mIoU: 0.8627
# Summary Epoch [17/60] - Avg Loss: 0.0367 - Avg mIoU: 0.8653
# Summary Epoch [18/60] - Avg Loss: 0.0398 - Avg mIoU: 0.8568
# Summary Epoch [19/60] - Avg Loss: 0.0397 - Avg mIoU: 0.8569
# Summary Epoch [20/60] - Avg Loss: 0.0363 - Avg mIoU: 0.8663
# Summary Epoch [21/60] - Avg Loss: 0.0348 - Avg mIoU: 0.8715
# Summary Epoch [22/60] - Avg Loss: 0.0348 - Avg mIoU: 0.8724
# Summary Epoch [23/60] - Avg Loss: 0.0340 - Avg mIoU: 0.8746
# Summary Epoch [24/60] - Avg Loss: 0.0308 - Avg mIoU: 0.8840
# Summary Epoch [25/60] - Avg Loss: 0.0298 - Avg mIoU: 0.8873
# Summary Epoch [26/60] - Avg Loss: 0.0329 - Avg mIoU: 0.8787
# Summary Epoch [27/60] - Avg Loss: 0.0360 - Avg mIoU: 0.8696
# Summary Epoch [28/60] - Avg Loss: 0.0306 - Avg mIoU: 0.8846
# Summary Epoch [29/60] - Avg Loss: 0.0285 - Avg mIoU: 0.8912
# Summary Epoch [30/60] - Avg Loss: 0.0273 - Avg mIoU: 0.8952
# Summary Epoch [31/60] - Avg Loss: 0.0269 - Avg mIoU: 0.8968
# Summary Epoch [32/60] - Avg Loss: 0.0260 - Avg mIoU: 0.8998
# Summary Epoch [33/60] - Avg Loss: 0.0247 - Avg mIoU: 0.9041
# Summary Epoch [34/60] - Avg Loss: 0.0240 - Avg mIoU: 0.9061
# Summary Epoch [35/60] - Avg Loss: 0.0252 - Avg mIoU: 0.9027
# Summary Epoch [36/60] - Avg Loss: 0.0261 - Avg mIoU: 0.9002
# Summary Epoch [37/60] - Avg Loss: 0.0355 - Avg mIoU: 0.8755
# Summary Epoch [38/60] - Avg Loss: 0.0287 - Avg mIoU: 0.8927
# Summary Epoch [39/60] - Avg Loss: 0.0244 - Avg mIoU: 0.9050
# Summary Epoch [40/60] - Avg Loss: 0.0230 - Avg mIoU: 0.9103
# Summary Epoch [41/60] - Avg Loss: 0.0219 - Avg mIoU: 0.9138
# Summary Epoch [42/60] - Avg Loss: 0.0214 - Avg mIoU: 0.9154
# Summary Epoch [43/60] - Avg Loss: 0.0210 - Avg mIoU: 0.9172
# Summary Epoch [44/60] - Avg Loss: 0.0208 - Avg mIoU: 0.9181
# Summary Epoch [45/60] - Avg Loss: 0.0202 - Avg mIoU: 0.9199
# Summary Epoch [46/60] - Avg Loss: 0.0203 - Avg mIoU: 0.9198
# Summary Epoch [47/60] - Avg Loss: 0.0201 - Avg mIoU: 0.9206
# Summary Epoch [48/60] - Avg Loss: 0.0195 - Avg mIoU: 0.9224
# Summary Epoch [49/60] - Avg Loss: 0.0209 - Avg mIoU: 0.9179
# Summary Epoch [50/60] - Avg Loss: 0.0210 - Avg mIoU: 0.9173
# Summary Epoch [51/60] - Avg Loss: 0.0206 - Avg mIoU: 0.9191
# Summary Epoch [52/60] - Avg Loss: 0.0188 - Avg mIoU: 0.9251
# Summary Epoch [53/60] - Avg Loss: 0.0184 - Avg mIoU: 0.9268
# Summary Epoch [54/60] - Avg Loss: 0.0294 - Avg mIoU: 0.9095
# Summary Epoch [55/60] - Avg Loss: 0.0357 - Avg mIoU: 0.8761
# Summary Epoch [56/60] - Avg Loss: 0.0226 - Avg mIoU: 0.9120
# Summary Epoch [57/60] - Avg Loss: 0.0191 - Avg mIoU: 0.9239
# Summary Epoch [58/60] - Avg Loss: 0.0179 - Avg mIoU: 0.9282
# Summary Epoch [59/60] - Avg Loss: 0.0177 - Avg mIoU: 0.9290
# Summary Epoch [60/60] - Avg Loss: 0.0169 - Avg mIoU: 0.9319
